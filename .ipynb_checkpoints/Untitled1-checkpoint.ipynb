# %%
import pandas as pd 
import numpy as np
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data=pd.read_csv('tmdb_5000_movies.csv')

# %%
def moviewords(col):
    new_col=[]
    for i in data[col]:
        i=str(i)
        i=i.lower()
        i=re.sub('[0-9]', '', i)
        i=re.sub('name|id', '', i)
        i=re.sub('{"": , "": "|"}', '', i)
        i=re.sub('\\[|\\]', '', i)
        i=re.sub('{"": "|", "": }', '', i)
        new_col.append(i)
    return new_col

# %%
modify=data[['id', 'title', 'overview', 'popularity', 'budget', 'revenue',
             'runtime', 'vote_average', 'vote_count']]

# %%
modify
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#          budget     revenue  runtime  vote_average  vote_count
# 0     237000000  2787965087    162.0           7.2       11800
# 1     300000000   961000000    169.0           6.9        4500
# 2     245000000   880674609    148.0           6.3        4466
# 3     250000000  1084939099    165.0           7.6        9106
# 4     260000000   284139100    132.0           6.1        2124
# ...         ...         ...      ...           ...         ...
# 4798     220000     2040920     81.0           6.6         238
# 4799       9000           0     85.0           5.9           5
# 4800          0           0    120.0           7.0           6
# 4801          0           0     98.0           5.7           7
# 4802          0           0     90.0           6.3          16
#
# [4803 rows x 9 columns]

# %%
modify['genres']=moviewords('genres')
modify['keywords']=moviewords('keywords')
modify['production_companies']=moviewords('production_companies')
modify['features']=modify['keywords']+modify['production_companies']+modify['genres']+modify['title']
modify['index']=list(range(0, len(modify)))
modify=modify.drop_duplicates()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
print(modify.dtypes)
# Out:
# id                        int64
# title                    object
# overview                 object
# popularity              float64
# budget                    int64
# revenue                   int64
# runtime                 float64
# vote_average            float64
# vote_count                int64
# genres                   object
# keywords                 object
# production_companies     object
# features                 object
# index                     int64
# dtype: object

# %%
modify
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#          budget     revenue  runtime  vote_average  vote_count  \
# 0     237000000  2787965087    162.0           7.2       11800
# 1     300000000   961000000    169.0           6.9        4500
# 2     245000000   880674609    148.0           6.3        4466
# 3     250000000  1084939099    165.0           7.6        9106
# 4     260000000   284139100    132.0           6.1        2124
# ...         ...         ...      ...           ...         ...
# 4798     220000     2040920     81.0           6.6         238
# 4799       9000           0     85.0           5.9           5
# 4800          0           0    120.0           7.0           6
# 4801          0           0     98.0           5.7           7
# 4802          0           0     90.0           6.3          16
#
#                                            genres  \
# 0     action, adventure, fantasy, science fiction
# 1                      adventure, fantasy, action
# 2                        action, adventure, crime
# 3                  action, crime, drama, thriller
# 4              action, adventure, science fiction
# ...                                           ...
# 4798                      action, crime, thriller
# 4799                              comedy, romance
# 4800             comedy, drama, romance, tv movie
# 4801
# 4802                                  documentary
#
#                                                keywords  \
# 0     culture clash, future, space war, space colony...
# 1     ocean, drug abuse, exotic island, east india t...
# 2     spy, based on novel, secret agent, sequel, mi,...
# 3     dc comics, crime fighter, terrorist, secret en...
# 4     based on novel, mars, medallion, space travel,...
# ...                                                 ...
# 4798  united states\umexico barrier, legs, arms, pap...
# 4799
# 4800  date, love at first sight, narration, investig...
# 4801
# 4802            obsession, camcorder, crush, dream girl
#
#                                    production_companies  \
# 0     ingenious film partners, twentieth century fox...
# 1     walt disney pictures, jerry bruckheimer films,...
# 2                          columbia pictures, danjaq, b
# 3     legendary pictures, warner bros., dc entertain...
# 4                                  walt disney pictures
# ...                                                 ...
# 4798                                  columbia pictures
# 4799
# 4800  front street pictures, muse entertainment ente...
# 4801
# 4802         rusty bear entertainment, lucky crow films
#
#                                                features  index
# 0     culture clash, future, space war, space colony...      0
# 1     ocean, drug abuse, exotic island, east india t...      1
# 2     spy, based on novel, secret agent, sequel, mi,...      2
# 3     dc comics, crime fighter, terrorist, secret en...      3
# 4     based on novel, mars, medallion, space travel,...      4
# ...                                                 ...    ...
# 4798  united states\umexico barrier, legs, arms, pap...   4798
# 4799                           comedy, romanceNewlyweds   4799
# 4800  date, love at first sight, narration, investig...   4800
# 4801                                   Shanghai Calling   4801
# 4802  obsession, camcorder, crush, dream girlrusty b...   4802
#
# [4803 rows x 14 columns]

# %%
modify=modify.fillna('')

# %%
def movie_similar(movie_names):
    movie_1=modify[modify['title']==movie_names[0]]
    movie_2=modify[modify['title']==movie_names[1]]
    movies_df=pd.concat([movie_1, movie_2], axis=0)
    count_matrix=CountVectorizer().fit_transform(movies_df['features'])
    cosine_sim=np.round(cosine_similarity(count_matrix), 3)
    sim=cosine_sim[0,1]
    print(sim)
    return sim

# %%
def movie_recom(movie_names):
    count_matrix=CountVectorizer().fit_transform(modify['features'])
    cosine_sim=np.round(cosine_similarity(count_matrix), 3)
    def movie_index(title):
        return modify.index[modify['title']==title].values[0]
    for movie_name in movie_names:
        index=movie_index(movie_name)
        similar_movies=list(enumerate(cosine_sim[index]))
        similar_movies=pd.DataFrame(similar_movies, columns=['index', 'similarity'])
        similar_movies=pd.merge(similar_movies, modify[['index', 'title']], on='index')
        similar_movies=similar_movies.sort_values(by='similarity', ascending=False)
        print(similar_movies[1:10])
        print('\n')
        similar_movies = pd.merge(similar_movies[1:10], modify[['title','popularity','vote_average']], on="title")
    return similar_movies

# %%
movie=['Spider-Man', 'The Avengers']
movie_similar(movie)
movie_recom(movie)
# Out:
# 0.374
#      index  similarity                             title
# 5        5       0.442                      Spider-Man 3
# 16      16       0.374                      The Avengers
# 182    182       0.348                           Ant-Man
# 79      79       0.348                        Iron Man 2
# 30      30       0.341                      Spider-Man 2
# 20      20       0.340            The Amazing Spider-Man
# 805    805       0.321  Ghost Rider: Spirit of Vengeance
# 7        7       0.315           Avengers: Age of Ultron
# 68      68       0.311                          Iron Man
#
#
#      index  similarity                                title
# 182    182       0.746                              Ant-Man
# 79      79       0.640                           Iron Man 2
# 129    129       0.588                                 Thor
# 174    174       0.586                  The Incredible Hulk
# 126    126       0.577                 Thor: The Dark World
# 7        7       0.572              Avengers: Age of Ultron
# 85      85       0.551  Captain America: The Winter Soldier
# 169    169       0.511   Captain America: The First Avenger
# 68      68       0.507                             Iron Man
#    index  similarity                                title  popularity  \
# 0    182       0.746                              Ant-Man  120.093610
# 1     79       0.640                           Iron Man 2   77.300194
# 2    129       0.588                                 Thor   86.493424
# 3    174       0.586                  The Incredible Hulk   62.898336
# 4    126       0.577                 Thor: The Dark World   99.499595
# 5      7       0.572              Avengers: Age of Ultron  134.279229
# 6     85       0.551  Captain America: The Winter Soldier   72.225265
# 7    169       0.511   Captain America: The First Avenger   74.506246
# 8     68       0.507                             Iron Man  120.725053
#
#    vote_average
# 0           7.0
# 1           6.6
# 2           6.6
# 3           6.1
# 4           6.8
# 5           7.3
# 6           7.6
# 7           6.6
# 8           7.4
